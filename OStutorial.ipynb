# %%
import os

# %%
print(dir(os))
# Out:
# ['DirEntry', 'F_OK', 'MutableMapping', 'O_APPEND', 'O_BINARY', 'O_CREAT', 'O_EXCL', 'O_NOINHERIT', 'O_RANDOM', 'O_RDONLY', 'O_RDWR', 'O_SEQUENTIAL', 'O_SHORT_LIVED', 'O_TEMPORARY', 'O_TEXT', 'O_TRUNC', 'O_WRONLY', 'P_DETACH', 'P_NOWAIT', 'P_NOWAITO', 'P_OVERLAY', 'P_WAIT', 'PathLike', 'R_OK', 'SEEK_CUR', 'SEEK_END', 'SEEK_SET', 'TMP_MAX', 'W_OK', 'X_OK', '_AddedDllDirectory', '_Environ', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_check_methods', '_execvpe', '_exists', '_exit', '_fspath', '_get_exports_list', '_putenv', '_unsetenv', '_wrap_close', 'abc', 'abort', 'access', 'add_dll_directory', 'altsep', 'chdir', 'chmod', 'close', 'closerange', 'cpu_count', 'curdir', 'defpath', 'device_encoding', 'devnull', 'dup', 'dup2', 'environ', 'error', 'execl', 'execle', 'execlp', 'execlpe', 'execv', 'execve', 'execvp', 'execvpe', 'extsep', 'fdopen', 'fsdecode', 'fsencode', 'fspath', 'fstat', 'fsync', 'ftruncate', 'get_ex
# ...

# %%
print(os.getcwd())
# Out:
# C:\Users\emaem\OneDrive\Desktop\python modules

# %%
os.chdir('C:/Users/emaem/OneDrive/Desktop/')

# %%
print(os.listdir())
# Out:
# ['3702 Week 1 journal.docx', '6102', '6700', '6702', '6806 zoom', '6806CS', '6806myproject', 'BMI 6102 module 1.docx', 'BMI Memory+Module+1.pptx', 'desktop.ini', 'Discord.lnk', 'Dropbox.lnk', 'GitHub Desktop.lnk', 'Grammarly.lnk', 'IMG_4395.jpg', 'Kaltura Capture.lnk', 'Kindle.lnk', 'Microsoft Edge.lnk', 'MY PROJECT', 'Phone photo', 'python modules', 'PythonOS', 'School information', 'Screenshot 2020-09-04 18.30.33.png', 'Screenshot 2020-09-04 18.30.58.png', 'Screenshot 2020-09-04 18.34.18.png', 'Screenshot 2020-09-04 21.55.57.png', 'Syncios Data Transfer.lnk', 'verify MD.jpg', 'Video post.mp4', 'Visual Studio Code.lnk', 'Week 2']

# %%
os.mkdir('OS-Demo-2')

# %%
os.rmdir('OS-Demo-2')

# %%
os.makedirs('OS-Demo-2/Sub-Dir-1')

# %%
os.removedirs('OS-Demo-2/Sub-Dir-1')

# %%
os.rename('test.txt', 'demo.txt')

# %%
print(os.stat('demo.txt'))
# Out:
# os.stat_result(st_mode=33206, st_ino=3377699720995020, st_dev=3897249518, st_nlink=1, st_uid=0, st_gid=0, st_size=0, st_atime=1599329264, st_mtime=1599329264, st_ctime=1599329264)

# %%
print(os.stat('demo.txt').st_size)
# Out:
# 13

# %%
print(os.stat('demo.txt').st_mtime)
# Out:
# 1599329339.699516

# %%
mod_time = os.stat('demo.txt.txt').st_mtime

# %%
from datetime import datetime

# %%
print(datetime.fromtimestamp(mod_time))
# Out:
# 2020-09-05 11:09:29.724445

# %%
for dirpath, dirnames, filenames in os.walk('C:/Users/emaem/OneDrive/Desktop/'):
    print('Current Path:', dirpath)
    print('Directories:', dirnames)
    print('Files:', filenames)
    print()
# Out:
# Current Path: C:/Users/emaem/OneDrive/Desktop/
# Directories: ['6102', '6700', '6702', '6806 zoom', '6806CS', '6806myproject', 'MY PROJECT', 'Phone photo', 'python modules', 'PythonOS', 'School information', 'Week 2']
# Files: ['3702 Week 1 journal.docx', 'BMI 6102 module 1.docx', 'BMI Memory+Module+1.pptx', 'demo.txt', 'desktop.ini', 'Discord.lnk', 'Dropbox.lnk', 'GitHub Desktop.lnk', 'Grammarly.lnk', 'IMG_4395.jpg', 'Kaltura Capture.lnk', 'Kindle.lnk', 'Microsoft Edge.lnk', 'Screenshot 2020-09-04 18.30.33.png', 'Screenshot 2020-09-04 18.30.58.png', 'Screenshot 2020-09-04 18.34.18.png', 'Screenshot 2020-09-04 21.55.57.png', 'Syncios Data Transfer.lnk', 'verify MD.jpg', 'Video post.mp4', 'Visual Studio Code.lnk']
#
# Current Path: C:/Users/emaem/OneDrive/Desktop/6102
# Directories: ['lab 1']
# Files: ['Lab Post Assignment1.docx']
#
# Current Path: C:/Users/emaem/OneDrive/Desktop/6102\lab 1
# Directories: []
# ...

# %%
os.environ
# Out:
# environ{'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPDATA': 'C:\\Users\\emaem\\AppData\\Roaming',
#         'ASL.LOG': 'Destination=file',
#         'COMMONPROGRAMFILES': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': 'LAPTOP-6JIM5ETJ',
#         'COMSPEC': 'C:\\Windows\\system32\\cmd.exe',
#         'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#         'HOMEDRIVE': 'C:',
#         'HOMEPATH': '\\Users\\emaem',
#         'LOCALAPPDATA': 'C:\\Users\\emaem\\AppData\\Local',
#         'LOGONSERVER': '\\\\LAPTOP-6JIM5ETJ',
#         'NUMBER_OF_PROCESSORS': '8',
#         'ONEDRIVE': 'C:\\Users\\emaem\\OneDrive',
#         'ONEDRIVECONSUMER': 'C:\\Users\\emaem\\OneDrive',
#         'OS': 'Windows_NT',
# ...

# %%
print(os.environ.get('HOME'))
# Out:
# None

# %%
file_path = os.path.join(os.environ.get('HOME'), 'test.txt'
# Out:
#   File "<ipython-input-85-0251edac30a8>", line 1
#     file_path = os.path.join(os.environ.get('HOME'), 'test.txt'
#                                                                ^
# SyntaxError: unexpected EOF while parsing

# %%
print(os.path.basename('/tmp/test.txt'))
# Out:
# test.txt

# %%
print(os.path.dirname('/tmp/test.txt'))
# Out:
# /tmp

# %%
print(os.path.split('/tmp/test.txt'))
# Out:
# ('/tmp', 'test.txt')

# %%
print(os.path.exists('/tmp/test.txt'))
# Out:
# False

# %%
print(os.path.isdir('/tmp/python'))
# Out:
# False

# %%
print(os.path.isfile('/tmp/EMMA'))
# Out:
# False

# %%
print(os.path.splitext('/tmp/test.txt'))
# Out:
# ('/tmp/test', '.txt')

# %%
Python Documentation URL = https://www.python.org/doc/

# %%
OS Tutorial URL = https://docs.python.org/3/library/os.html?highlight=os%20module#module-os
